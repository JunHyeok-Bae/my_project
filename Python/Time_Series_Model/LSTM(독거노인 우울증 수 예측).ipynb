# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, r2_score


file_path = r'C:\Users\BAE J.H\Desktop\우울증예측1.xlsx'
data = pd.read_excel(file_path)

data['독거노인_우울증환자수'] = data['독거노인인구'] * (data['우울증환자수비율'] / 100)

depression_series = data['독거노인_우울증환자수'].values
years = data['연도'].values

scaler = MinMaxScaler(feature_range=(0, 1))
depression_series_scaled = scaler.fit_transform(depression_series.reshape(-1, 1))

def create_dataset(series, time_step=1):
    X, y = [], []
    for i in range(len(series) - time_step):
        X.append(series[i:(i + time_step), 0])
        y.append(series[i + time_step, 0])
    return np.array(X), np.array(y)


time_step = 8 
X, y = create_dataset(depression_series_scaled, time_step)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# LSTM 모델 사용
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=False, input_shape=(time_step, 1), dropout=0.2, recurrent_dropout=0.2))) 
model.add(Dense(units=1))
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('LSTM Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred_rescaled = scaler.inverse_transform(train_pred)
y_train_rescaled = scaler.inverse_transform(y_train.reshape(-1, 1))
test_pred_rescaled = scaler.inverse_transform(test_pred)
y_test_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))

plt.figure(figsize=(10, 6))
plt.plot(years[:train_size], y_train_rescaled, label='Train Actual', color='blue')

plt.plot(years[train_size:train_size+len(y_test_rescaled)], y_test_rescaled, label='Test Actual', color='green')

plt.plot(years[train_size:train_size+len(test_pred_rescaled)], test_pred_rescaled, label='Test Predicted', color='red', linestyle='--')
plt.xlabel('Year')
plt.ylabel('Depression Patients (Elderly Living Alone)')
plt.legend()
plt.title('LSTM Predictions vs Actual')
plt.show()

train_rmse = np.sqrt(mean_squared_error(y_train_rescaled, train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_rescaled, test_pred_rescaled))

forecast_years = list(range(2025, 2071))

forecast_rescaled = []
last_sequence = depression_series_scaled[-time_step:].reshape(1, time_step, 1)

for _ in forecast_years:
    forecast = model.predict(last_sequence)
    forecast_rescaled.append(forecast[0, 0])
    
    last_sequence = np.append(last_sequence[:, 1:, :], forecast.reshape(1, 1, 1), axis=1)

forecast_rescaled = scaler.inverse_transform(np.array(forecast_rescaled).reshape(-1, 1))

forecast_data = pd.DataFrame({
    '연도': forecast_years,
    '예측된_독거노인_우울증환자수': np.round(forecast_rescaled.flatten())
})

print(forecast_data)

output_file_path = r'C:\Users\BAE J.H\Desktop\독거노인_우울증예측_LSTM.xlsx'
forecast_data.to_excel(output_file_path, index=False)

print(f'2025~2080년 예측된 독거노인 우울증 환자 수 데이터가 {output_file_path}로 저장되었습니다.')

print(f'Train RMSE: {train_rmse}')
print(f'Test RMSE: {test_rmse}')

train_r2 = r2_score(y_train_rescaled, train_pred_rescaled)
test_r2 = r2_score(y_test_rescaled, test_pred_rescaled)

print(f'Train R²: {train_r2}')
print(f'Test R²: {test_r2}')
# Out:
# Epoch 1/100
# c:\conda\envs\ml\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.0783 - val_loss: 0.5509
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0621 - val_loss: 0.4590
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0439 - val_loss: 0.3736
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0297 - val_loss: 0.2946
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0197 - val_loss: 0.2224
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0096 - val_loss: 0.1585
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0095 - val_loss: 0.1040
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0051 - val_loss: 0.0637
# ...
